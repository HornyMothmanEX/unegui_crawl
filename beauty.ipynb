# %%
import httpx
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import requests
import re
import pandas as pd
import asyncio
from playwright.sync_api import sync_playwright

# %%
def get_links(link):
    with httpx.Client() as client:
        response = client.get(link)
        soup = BeautifulSoup(response.text, 'html.parser')
        urls = []

        main = soup.find('div', class_='container p-0')

        if main:
            for a_tag in main.find_all('a', href=True):
                full_url = urljoin(link, a_tag['href'])
                urls.append(full_url)

    return urls

def product_links(link):
    with httpx.Client() as client:
        response = client.get(link)
        soup = BeautifulSoup(response.text, 'html.parser')
        urls = []
        
        # Find all "viewMore" sections on the page
        view_more_sections = soup.find_all('div', class_='viewMore')
        
        for section in view_more_sections:
            # Extract links from each "viewMore" section
            for a_tag in section.find_all('a', href=True):
                full_url = urljoin(link, a_tag['href'])
                urls.append(full_url)
                
    return urls


def find_other_ingredients(soup):
    p_tags = soup.find_all('p')
    extracted_text = []
    in_target_section = False

    for p in p_tags:
        text = p.get_text(strip=True)
        if 'Other Ingredients' in text:
            in_target_section = True
            # Remove "Other Ingredients" label and add the following text
            extracted_text.append(text.replace("Other Ingredients", "").strip())
        elif 'Ingredients' in text:
            in_target_section = True
            # Remove "Other Ingredients" label and add the following text
            extracted_text.append(text.replace("Ingredients:", "").strip())
        elif 'Precaution' in text or 'Storage' in text:
            # Stop extraction once "Storage" is found
            break
        elif in_target_section:
            extracted_text.append(text)


    cleaned_text = ' '.join(extracted_text).replace('&nbsp;', ' ').strip().lower()
    return cleaned_text

def get_best_for(soup, label):
    # Find the element containing the label
    label_element = soup.find(string=lambda text: text and label in text)
    
    if label_element:
        # Find the parent of the label element to start navigating from
        parent = label_element.find_parent()
        
        # Iterate through siblings of the parent
        for sibling in parent.find_all_next():
            if sibling.name == 'ul':
                # Capture and return the concatenated text from all list items in the unordered list
                return ' '.join(li.get_text(strip=True) for li in sibling.find_all('li'))
    
    return ''



def get_text_after_label(soup, label):
    # Find the element containing the label
    label_element = soup.find(string=lambda text: text and label in text)
    
    if label_element:
        # Find the parent of the label element to start navigating from
        parent = label_element.find_parent()
        
        # Iterate through siblings of the parent
        for sibling in parent.find_all_next():
            if sibling.name == 'p':
                # Return text from the first relevant sibling found
                return sibling.get_text(strip=True)
            elif sibling.name == 'hr':
                # Stop if an 'hr' tag is encountered (end of section)
                break
    
    return ''

def extract_manufactured_nation(soup):
    manufactured_in_text = ""
    p_tags = soup.find_all('p')

    for p in p_tags:
        text = p.get_text(strip=True)
        if 'Manufactured in' in text:
            # Extract everything after "Manufactured in"
            manufactured_in_text = text.split('Manufactured in')[-1].strip()
            break

    return manufactured_in_text if manufactured_in_text else ''

# %%
beauty = 'https://www.lac.com/en/everyday-wellness.html/'
urls = get_links(beauty)
all_links = []

# %%
for i in urls:
    links_from_product = product_links(i)
    all_links.extend(links_from_product)  # Flatten the list of links
print(f"Total links found: {len(all_links)}")
# Out:
# Total links found: 467

# %%
with open('links.txt', 'w') as file:
    for link in all_links:
        file.write(link + '\n')

# %%
all_details = []  # List to store details of each product

try:
    with httpx.Client() as client:
        for i, link in enumerate(all_links[:10]):  # Loop through the first 10 links
            source = client.get(link)
            soup = BeautifulSoup(source.text, 'html.parser')
            detail = {}

            content = soup.find('div', class_='fade show')

            try:
                id_num = content.find('span', class_='product-id text--bold')
                detail['id'] = id_num.text if id_num else None
            except Exception as e:
                print(f"Error finding product ID for link {i + 1}: {e}")

            try:
                name = soup.find('div', class_='d-none d-sm-block').h1.text
                detail['product_name'] = name
            except Exception as e:
                print(f"Error finding product name for link {i + 1}: {e}")

            try:
                brand = soup.find('div', class_='d-none d-sm-block').a.text
                detail['brand'] = brand
            except Exception as e:
                print(f"Error finding brand for link {i + 1}: {e}")

            try:
                breadcrumb = soup.find('ol', class_='breadcrumb text-size--small col', itemprop='category')
                model = breadcrumb.find_all('li', class_='breadcrumb-element')
                product_type = re.sub(r'\s+', ' ', model[-2].text.strip())
                detail['type'] = product_type
            except Exception as e:
                print(f"Error finding product type for link {i + 1}: {e}")

            try:
                price = soup.find('span', itemprop='price', class_='d-none').text
                detail['usual_price'] = price
            except Exception as e:
                print(f"Error finding usual price for link {i + 1}: {e}")

            try:
                vip_price = soup.find('span', itemprop='sale_price', class_='d-none').text
                detail['vip_price'] = vip_price
            except Exception as e:
                print(f"Error finding VIP price for link {i + 1}: {e}")

            divs1 = soup.find_all('div', class_='col-sm-12 col-md-4 col-lg-2 d-flex d-md-block justify-content-between pb-2')

            for div in divs1:
                try:
                    label = div.find('span', class_='d-block product-overview--label')
                    if label and label.text == "Form":
                        bold_span = div.find('span', class_='text--bold')
                        if bold_span and bold_span.a:
                            form = bold_span.a.text.strip()
                            detail['form'] = form
                except Exception as e:
                    print(f"Error finding form for link {i + 1}: {e}")

            
            try:
                servings = soup.find('div', class_='product-uom d-none').text
                detail['servings_per_container'] = servings
            except Exception as e:
                print(f"Error finding servings per container for link {i + 1}: {e}")

            
            try:
                usage = soup.find('div', id='product-usagedirection').text
                detail['usage_direction'] = usage
            except Exception as e:
                print(f"Error finding usage direction for link {i + 1}: {e}")

            try:
                key_ingredient_list = soup.find_all('div', class_='ingredient')
                key_ingredient = [div.find('a').text.strip() for div in key_ingredient_list]
                # Join the list into a single string, separating each ingredient with a comma
                key_ingredient = ', '.join(key_ingredient)
                key_ingredient = re.sub(r'\s+', ' ', key_ingredient.strip())
                detail['key_ingredient'] = key_ingredient
            except Exception as e:
                print(f"Error finding key ingredient for link {i + 1}: {e}")

            try:
                other_ingredient_section = soup.find('div', id='product-supplements')
                other_ingredients = find_other_ingredients(other_ingredient_section)
                detail['other_ingredients'] = other_ingredients
            except Exception as e:
                print(f"Error finding other ingredients for link {i + 1}: {e}")

           

            try:
                detail['storage'] = get_text_after_label(soup, "Storage")
                detail['precaution'] = get_text_after_label(soup, "Precaution")
                detail['best_for'] = get_best_for(soup, 'Best for people with')
                detail['manufacturer'] = extract_manufactured_nation(soup)
            except Exception as e:
                print(f"Error finding additional details for link {i + 1}: {e}")

            try:
                usp_list = soup.find_all('div', class_='usp-list-label')
                usp_texts = [div.find('span').text.strip() for div in usp_list]
                joined_usp_texts = ', '.join(usp_texts)
                detail['feature'] = joined_usp_texts
            except Exception as e:
                print(f"Error finding USP texts for link {i + 1}: {e}")
            
            try:
                detail['link'] = all_links[i]
            except:
                print(f"Error finding link {i + 1}: {e}")
            all_details.append(detail)  # Add the detail dictionary to the list

except Exception as e:
    print(f"General error occurred: {e}")

# Display all collected details
all_details
# Out:
# Error finding brand for link 1: 'NoneType' object has no attribute 'text'
# Error finding usual price for link 1: 'NoneType' object has no attribute 'text'
# Error finding VIP price for link 1: 'NoneType' object has no attribute 'text'
# Error finding servings per container for link 1: 'NoneType' object has no attribute 'text'
# Error finding usage direction for link 1: 'NoneType' object has no attribute 'text'
# Error finding other ingredients for link 1: 'NoneType' object has no attribute 'find_all'
# [{'id': None,
#   'product_name': '16-day Transformation',
#   'type': 'Anti Ageing',
#   'key_ingredient': '',
#   'storage': '',
#   'precaution': '',
#   'best_for': '',
#   'manufacturer': '',
#   'feature': '',
#   'link': 'https://www.lac.com/en/promotions_bundles/16-day-transformation-BUNDLE1_taut16daystransformation.html?catId=everyday-wellness_anti-ageing'},
#  {'id': '01400940',
#   'product_name': 'French Pine Bark Extract - The Powerful Antioxidant',
#   'brand': "LAC MASQUELIER's®",
#   'type': 'Anti Ageing',
#   'usual_price': '35.38',
#   'vip_price': '28.30',
#   'form': 'Tablet',
#   'servings_per_container': '25 tablets',
#   'usage_direction': 'Take 1 – 2 tablets per day with water or fruit juice, or at least 1 tablet for every 100lb (45 kg) of body weight.',
#   'key_ingredient': 'Oligomeric proanthocyanidin complexes (OPCs)',
#   'other_ingredients': 'microcrystalline cellulose, magnesium stearate  colour of tablet may vary from batch to batch due to natural ingredients used  certified free of yeast, wheat, corn, milk, egg, soy, gluten, animal derivatives, sugar, starch. suitable for vegetarians, no artificial colours and preservatives.',
#   'storage': 'Store in a cool, dry place away from direct sunlight. Keep out of reach of children.',
#   'precaution': 'If you are pregnant, nursing, taking any medication or have a medical condition, please consult a physician before using this product.',
#   'best_for': '',
#   'manufacturer': 'The Netherlands',
#   'feature': "Premium Grade, Vegetarian, No Preservatives, No Artifical Colours, MASQUELIER'S® Original OPCs, Fight Against Free Radicals, Improve Blood Circulation, Strengthen Collagen Matrix",
#   'link': 'https://www.lac.com/en/anti-ageing/lac-masquelier%27s%C2%AE/french-pine-bark-extract---the-powerful-antioxidant-01400940.html?catId=everyday-wellness_anti-ageing'},
#  {'id': '01400030',
#   'product_name': 'French Pine Bark Extract - The Powerful Antioxidant',
#   'brand': "LAC MASQUELIER's®",
#   'type': 'Anti Ageing',
#   'usual_price': '73.04',
#   'vip_price': '58.43',
#   'form': 'Tablet',
#   'servings_per_container': '50 tablets',
#   'usage_direction': 'Take 1 – 2 tablets per day with water or fruit juice, or at least 1 tablet for every 100lb (45 kg) of body weight.',
#   'key_ingredient': 'Oligomeric proanthocyanidin complexes (OPCs)',
#   'other_ingredients': 'microcrystalline cellulose, magnesium stearate  colour of tablet may vary from batch to batch due to natural ingredients used  certified free of yeast, wheat, corn, milk, egg, soy, gluten, animal derivatives, sugar, starch. suitable for vegetarians, no artificial colours and preservatives.',
#   'storage': 'Store in a cool, dry place away from direct sunlight. Keep out of reach of children.',
#   'precaution': 'If you are pregnant, nursing, taking any medication or have a medical condition, please consult a physician before using this product.',
#   'best_for': '',
#   'manufacturer': 'The Netherlands',
#   'feature': "Premium Grade, Vegetarian, No Preservatives, No Artifical Colours, MASQUELIER'S® Original OPCs, Fight Against Free Radicals, Improve Blood Circulation, Strengthen Collagen Matrix",
#   'link': 'https://www.lac.com/en/anti-ageing/lac-masquelier%27s%C2%AE/french-pine-bark-extract---the-powerful-antioxidant-01400030.html?catId=everyday-wellness_anti-ageing'},
#  {'id': '01400240',
#   'product_name': 'French Pine Bark Extract - The Powerful Antioxidant',
#   'brand': "LAC MASQUELIER's®",
#   'type': 'Anti Ageing',
#   'usual_price': '243.81',
#   'vip_price': '195.05',
#   'form': 'Tablet',
#   'servings_per_container': '175 tablets',
#   'usage_direction': 'Take 1 – 2 tablets per day with water or fruit juice, or at least 1 tablet for every 100lb (45 kg) of body weight.',
#   'key_ingredient': 'Oligomeric proanthocyanidin complexes (OPCs)',
#   'other_ingredients': 'microcrystalline cellulose, magnesium stearate  colour of tablet may vary from batch to batch due to natural ingredients used  certified free of yeast, wheat, corn, milk, egg, soy, gluten, animal derivatives, sugar, starch. suitable for vegetarians, no artificial colours and preservatives.',
#   'storage': 'Store in a cool, dry place away from direct sunlight. Keep out of reach of children.',
#   'precaution': 'If you are pregnant, nursing, taking any medication or have a medical condition, please consult a physician before using this product.',
#   'best_for': '',
#   'manufacturer': 'The Netherlands',
#   'feature': "Premium Grade, Vegetarian, No Preservatives, No Artifical Colours, MASQUELIER'S® Original OPCs, Fight Against Free Radicals, Improve Blood Circulation, Strengthen Collagen Matrix",
#   'link': 'https://www.lac.com/en/anti-ageing_beauty/lac-masquelier%27s%C2%AE/french-pine-bark-extract---the-powerful-antioxidant-01400240.html?catId=everyday-wellness_anti-ageing'},
#  {'id': '01400140',
#   'product_name': 'French Pine Bark Extract - The Powerful Antioxidant',
#   'brand': "LAC MASQUELIER's®",
#   'type': 'Anti Ageing',
#   'usual_price': '391.92',
#   'vip_price': '313.54',
#   'form': 'Tablet',
#   'servings_per_container': '300 tablets',
#   'usage_direction': 'Directions: As a dietary supplement, take 1 – 2 tablets per day with water or fruit juice, or at least 1 tablet for every 100lb (45 kg) of body weight.',
#   'key_ingredient': 'Oligomeric proanthocyanidin complexes (OPCs)',
#   'other_ingredients': 'microcrystalline cellulose, magnesium stearate  colour of tablet may vary from batch to batch due to natural ingredients used  certified free of yeast, wheat, corn, milk, egg, soy, gluten, animal derivatives, sugar, starch. suitable for vegetarians, no artificial colours and preservatives.',
#   'storage': 'Store in a cool, dry place. Avoid direct sunlight. Keep out of children’s reach.',
#   'precaution': 'If you are pregnant, nursing, taking any medication or have a medical condition, please consult a physician before using this product.',
#   'best_for': '',
#   'manufacturer': 'The Netherlands',
#   'feature': "Premium Grade, Vegetarian, No Preservatives, No Artifical Colours, MASQUELIER'S® Original OPCs, Fight Against Free Radicals, Improve Blood Circulation, Strengthen Collagen Matrix",
#   'link': 'https://www.lac.com/en/anti-ageing/lac-masquelier%27s%C2%AE/french-pine-bark-extract---the-powerful-antioxidant-01400140.html?catId=everyday-wellness_anti-ageing'},
#  {'id': '01406620',
#   'product_name': 'Miracle Intensive Age-Defying Serum',
#   'brand': 'LAC TAUT®',
#   'type': 'Anti Ageing',
#   'usual_price': '72.27',
#   'vip_price': '0.00',
#   'form': 'Topical',
#   'servings_per_container': '40 ml',
#   'usage_direction': 'Pump once or twice onto palm. Rub palms together and pat gently onto cleansed, slightly damp skin on your face, neck and décolleté until fully absorbed.\n \nUse morning and night before your regular moisturizer. For unparalleled results, use it with LAC Taut® Premium Collagen range of supplements.',
#   'key_ingredient': 'Collagen, Glycerin, Sodium Hyaluronate, Tocopherols, Squalene (Shark Liver Oil)',
#   'other_ingredients': 'water, butylene glycol, glycerin, citric acid, sodium citrate, carbomer, xanthan gum, peg-40 hydrogenated castor oil, polyglyceryl-2 oleate, sodium hydroxide, betain, sodium dilauramidoglutamide lysine, sodium hyaluronate, soluble collagen, hydrolyzed collagen, phenoxyethanol, magnesium ascorbyl phosphate, triethylhexanoin, squalene, phytosteryl / behenyl / octyldodesyl lauroyl glutamate, tocopherol, methylparaben, ethylparaben',
#   'storage': 'Store in a cool, dry place away from direct sunlight. Keep out of reach of children.',
#   'precaution': 'For external use only. Avoid contact with eyes. If contact occurs, rinse thoroughly with water. Consult your physician and discontinue use if signs of irritation or rash occur.',
#   'best_for': '',
#   'manufacturer': 'Japan',
#   'feature': 'Premium Grade, Men and Women of all Ages, No Artifical Colours, Fragrance Free',
#   'link': 'https://www.lac.com/en/beauty/lac-taut%C2%AE/miracle-intensive-age-defying-serum-01406620.html?catId=everyday-wellness_anti-ageing'},
#  {'id': '01406400',
#   'product_name': 'NMN 300mg - Ultimate NAD+ Booster',
#   'brand': 'LAC Anti-Ageing',
#   'type': 'Anti Ageing',
#   'usual_price': '295.80',
#   'vip_price': '295.77',
#   'form': 'Softgel',
#   'servings_per_container': '30 softgels',
#   'usage_direction': 'Take 1 softgel daily.',
#   'key_ingredient': 'NMN (Nicotinamide Mononucleotide), Grape Seed Extract, Vitamin C, Vitamin E (Tocopherol)',
#   'other_ingredients': 'grape seed oil, glycerol, silicon dioxide, gelatin',
#   'storage': 'Store in a cool, dry place away from direct sunlight.\xa0Keep out of children’s reach.',
#   'precaution': 'If you are pregnant, nursing, taking any medication or have a medical condition; please consult a physician before using this product.',
#   'best_for': 'A sedentary lifestyle Age-related weight concerns Blood sugar concerns Liver health concerns Premature ageing symptoms',
#   'manufacturer': 'Japan',
#   'feature': 'No Artifical Colours, No Artificial Flavours, No Preservatives',
#   'link': 'https://www.lac.com/en/anti-ageing_beauty/lac-anti-ageing/nmn-300mg---ultimate-nad%2B-booster-01406400.html?catId=everyday-wellness_anti-ageing'},
#  {'id': '01403970',
#   'product_name': 'NMN 450mg - Ultimate NAD+ Booster',
#   'brand': 'LAC Anti-Ageing',
#   'type': 'Anti Ageing',
#   'usual_price': '385.77',
#   'vip_price': '308.62',
#   'servings_per_container': '1.5g x 30 powder sticks',
#   'usage_direction': 'Take 1 stick daily with juice or your favourite beverage.',
#   'key_ingredient': 'NMN (Nicotinamide Mononucleotide)',
#   'other_ingredients': 'indigestible dextrin, orange juice powder, monk fruit extract, orange flavour, silicon dioxide, tricalcium phosphate',
#   'storage': 'Store in a cool, dry place away from direct sunlight.\xa0Keep out of children’s reach.',
#   'precaution': 'If you are pregnant, nursing, taking any medication or have a medical condition; please consult a physician before using this product.',
#   'best_for': 'A sedentary lifestyle Age-related weight concerns Blood sugar concerns Liver health concerns Premature ageing symptoms',
#   'manufacturer': 'Japan',
#   'feature': 'Vegetarian, No Artificial Flavours, No Preservatives, Sachet',
#   'link': 'https://www.lac.com/en/anti-ageing/lac-anti-ageing/nmn-450mg---ultimate-nad%2B-booster-01403970.html?catId=everyday-wellness_anti-ageing'},
#  {'id': '01400670',
#   'product_name': 'Radiance+ Premium Collagen Mask',
#   'brand': 'LAC Taut®',
#   'type': 'Anti Ageing',
#   'usual_price': '38.85',
#   'vip_price': '31.08',
#   'form': 'Topical',
#   'servings_per_container': '5 sheets per box',
#   'usage_direction': 'Use on cleansed face. Gently fit mask over eye area, smoothing it to fit the curves of your face comfortably. Cover your eyes with the mask and relax. Leave the mask to do its magic for the next 7 minutes, followed by your favourite moisturiser routine.\xa0\n\xa0\nFor best results, use mask at least twice a week, together with LAC Taut® Premium Collagen range of products.\xa0',
#   'key_ingredient': 'Collagen, Glycerin, Sodium Hyaluronate, Tocopherols',
#   'other_ingredients': 'ingredients water, butylene glycol, glycerin, soluble collagen, hydrolysed collagen, betain, sodium dilauramidoglutamide lysine, sodium hyaluronate, magnesium ascorbly phosphate, squalane, triethylhexanoin, phytosteryl/behenyl/octyldodesyl/lauroyl glutamate, tocopherol, citric acid, sodium citrate, sodium hydroxide, carbomer, xanthan gum, peg-40 hydrogenated castor oil, polyglyceryl-2 oleate, phenoxy-ethanol, methylparaben, ethylparaben',
#   'storage': 'Store in a cool, dry place away from direct sunlight.\xa0Keep out of children’s reach.',
#   'precaution': 'For external use only. Avoid direct contact with eyes. If contact occurs, rinse thoroughly with water. Consult your physician and discontinue use if signs of irritation or rash occur.',
#   'best_for': '',
#   'manufacturer': 'Japan',
#   'feature': 'Premium Grade, Men and Women of all Ages',
#   'link': 'https://www.lac.com/en/beauty/lac-taut%C2%AE/radiance%2B-premium-collagen-mask-01400670.html?catId=everyday-wellness_anti-ageing'},
#  {'id': '01403960',
#   'product_name': 'Rejuvenate+ Premium Collagen 13,000mg plus Placenta & AG Complex',
#   'brand': 'LAC Taut®',
#   'type': 'Anti Ageing',
#   'usual_price': '77.65',
#   'vip_price': '62.12',
#   'form': 'Liquid',
#   'servings_per_container': '50ml x 8 bottles',
#   'usage_direction': 'Take 1 bottle, preferably before bedtime, at least 3-4 times a week. Shake well before drinking; drink immediately upon opening. \n',
#   'key_ingredient': 'Collagen, Mangosteen Extract, Placenta, Hyaluronic Acid, CoQ10 (Coenzyme Q-10), DNA (Albino Protein Extract), Ceramide, Vitamin C, Vitamin E (Tocopherol), Vitamin B-1 (Thiamin), Vitamin B-2 (Riboflavin), Vitamin B-6',
#   'other_ingredients': 'citric acid, malic acid, sodium benzoate, orange juice, orange flavour, isomaltooligosaccharide, sucralose, dextrin and water',
#   'storage': 'Store in a cool, dry place. Avoid direct sunlight. Keep out of children’s reach. Once opened, please keep refrigerated.',
#   'precaution': 'If you are allergic to seafood, consult your doctor before using Taut. Not suitable for pregnant or lactating women. Do not take while on Warfarin therapy without medical advice.',
#   'best_for': '',
#   'manufacturer': 'Japan',
#   'feature': 'Premium Grade, RDS® Premium Collagen, No Artificial Flavours, No Artifical Colours, No Pork, Beef or Chicken, Gluten Free, Men and Women of all Ages, Orange Flavour',
#   'link': 'https://www.lac.com/en/beauty_collagen/lac-taut%C2%AE/rejuvenate%2B-premium-collagen-13%2C000mg-plus-placenta-%26-ag-complex-01403960.html?catId=everyday-wellness_anti-ageing'}]

# %%
df = pd.DataFrame(all_details)
df
# Out:
#          id                                       product_name         type  \
# 0      None                              16-day Transformation  Anti Ageing
# 1  01400940  French Pine Bark Extract - The Powerful Antiox...  Anti Ageing
# 2  01400030  French Pine Bark Extract - The Powerful Antiox...  Anti Ageing
# 3  01400240  French Pine Bark Extract - The Powerful Antiox...  Anti Ageing
# 4  01400140  French Pine Bark Extract - The Powerful Antiox...  Anti Ageing
# 5  01406620                Miracle Intensive Age-Defying Serum  Anti Ageing
# 6  01406400                  NMN 300mg - Ultimate NAD+ Booster  Anti Ageing
# 7  01403970                  NMN 450mg - Ultimate NAD+ Booster  Anti Ageing
# 8  01400670                    Radiance+ Premium Collagen Mask  Anti Ageing
# 9  01403960  Rejuvenate+ Premium Collagen 13,000mg plus Pla...  Anti Ageing
#
#                                       key_ingredient  \
# 0
# 1       Oligomeric proanthocyanidin complexes (OPCs)
# 2       Oligomeric proanthocyanidin complexes (OPCs)
# 3       Oligomeric proanthocyanidin complexes (OPCs)
# 4       Oligomeric proanthocyanidin complexes (OPCs)
# 5  Collagen, Glycerin, Sodium Hyaluronate, Tocoph...
# 6  NMN (Nicotinamide Mononucleotide), Grape Seed ...
# 7                  NMN (Nicotinamide Mononucleotide)
# 8  Collagen, Glycerin, Sodium Hyaluronate, Tocoph...
# 9  Collagen, Mangosteen Extract, Placenta, Hyalur...
#
#                                              storage  \
# 0
# 1  Store in a cool, dry place away from direct su...
# 2  Store in a cool, dry place away from direct su...
# 3  Store in a cool, dry place away from direct su...
# 4  Store in a cool, dry place. Avoid direct sunli...
# 5  Store in a cool, dry place away from direct su...
# 6  Store in a cool, dry place away from direct su...
# 7  Store in a cool, dry place away from direct su...
# 8  Store in a cool, dry place away from direct su...
# 9  Store in a cool, dry place. Avoid direct sunli...
#
#                                           precaution  \
# 0
# 1  If you are pregnant, nursing, taking any medic...
# 2  If you are pregnant, nursing, taking any medic...
# 3  If you are pregnant, nursing, taking any medic...
# 4  If you are pregnant, nursing, taking any medic...
# 5  For external use only. Avoid contact with eyes...
# 6  If you are pregnant, nursing, taking any medic...
# 7  If you are pregnant, nursing, taking any medic...
# 8  For external use only. Avoid direct contact wi...
# 9  If you are allergic to seafood, consult your d...
#
#                                             best_for     manufacturer  \
# 0
# 1                                                     The Netherlands
# 2                                                     The Netherlands
# 3                                                     The Netherlands
# 4                                                     The Netherlands
# 5                                                               Japan
# 6  A sedentary lifestyle Age-related weight conce...            Japan
# 7  A sedentary lifestyle Age-related weight conce...            Japan
# 8                                                               Japan
# 9                                                               Japan
#
#                                              feature  \
# 0
# 1  Premium Grade, Vegetarian, No Preservatives, N...
# 2  Premium Grade, Vegetarian, No Preservatives, N...
# 3  Premium Grade, Vegetarian, No Preservatives, N...
# 4  Premium Grade, Vegetarian, No Preservatives, N...
# 5  Premium Grade, Men and Women of all Ages, No A...
# 6  No Artifical Colours, No Artificial Flavours, ...
# 7  Vegetarian, No Artificial Flavours, No Preserv...
# 8           Premium Grade, Men and Women of all Ages
# 9  Premium Grade, RDS® Premium Collagen, No Artif...
#
#                                                 link              brand  \
# 0  https://www.lac.com/en/promotions_bundles/16-d...                NaN
# 1  https://www.lac.com/en/anti-ageing/lac-masquel...  LAC MASQUELIER's®
# 2  https://www.lac.com/en/anti-ageing/lac-masquel...  LAC MASQUELIER's®
# 3  https://www.lac.com/en/anti-ageing_beauty/lac-...  LAC MASQUELIER's®
# 4  https://www.lac.com/en/anti-ageing/lac-masquel...  LAC MASQUELIER's®
# 5  https://www.lac.com/en/beauty/lac-taut%C2%AE/m...          LAC TAUT®
# 6  https://www.lac.com/en/anti-ageing_beauty/lac-...    LAC Anti-Ageing
# 7  https://www.lac.com/en/anti-ageing/lac-anti-ag...    LAC Anti-Ageing
# 8  https://www.lac.com/en/beauty/lac-taut%C2%AE/r...          LAC Taut®
# 9  https://www.lac.com/en/beauty_collagen/lac-tau...          LAC Taut®
#
#   usual_price vip_price     form   servings_per_container  \
# 0         NaN       NaN      NaN                      NaN
# 1       35.38     28.30   Tablet               25 tablets
# 2       73.04     58.43   Tablet               50 tablets
# 3      243.81    195.05   Tablet              175 tablets
# 4      391.92    313.54   Tablet              300 tablets
# 5       72.27      0.00  Topical                    40 ml
# 6      295.80    295.77  Softgel              30 softgels
# 7      385.77    308.62      NaN  1.5g x 30 powder sticks
# 8       38.85     31.08  Topical         5 sheets per box
# 9       77.65     62.12   Liquid         50ml x 8 bottles
#
#                                      usage_direction  \
# 0                                                NaN
# 1  Take 1 – 2 tablets per day with water or fruit...
# 2  Take 1 – 2 tablets per day with water or fruit...
# 3  Take 1 – 2 tablets per day with water or fruit...
# 4  Directions: As a dietary supplement, take 1 – ...
# 5  Pump once or twice onto palm. Rub palms togeth...
# 6                              Take 1 softgel daily.
# 7  Take 1 stick daily with juice or your favourit...
# 8  Use on cleansed face. Gently fit mask over eye...
# 9  Take 1 bottle, preferably before bedtime, at l...
#
#                                    other_ingredients
# 0                                                NaN
# 1  microcrystalline cellulose, magnesium stearate...
# 2  microcrystalline cellulose, magnesium stearate...
# 3  microcrystalline cellulose, magnesium stearate...
# 4  microcrystalline cellulose, magnesium stearate...
# 5  water, butylene glycol, glycerin, citric acid,...
# 6  grape seed oil, glycerol, silicon dioxide, gel...
# 7  indigestible dextrin, orange juice powder, mon...
# 8  ingredients water, butylene glycol, glycerin, ...
# 9  citric acid, malic acid, sodium benzoate, oran...

# %%
df.columns
# Out:
# Index(['id', 'product_name', 'type', 'key_ingredient', 'storage', 'precaution',
#        'best_for', 'manufacturer', 'feature', 'link', 'brand', 'usual_price',
#        'vip_price', 'form', 'servings_per_container', 'usage_direction',
#        'other_ingredients'],
#       dtype='object')

# %%
df_merged = df.groupby('id').agg({
    'product_name': 'first',
    'type': ', '.join,
    'key_ingredient': 'first',
    'storage': 'first',
    'precaution': 'first',
    'best_for': 'first',
    'manufacturer': 'first',
    'feature': 'first',
    'link': ', '.join,
    'brand': 'first',
    'usual_price': 'first',
    'vip_price': 'first',
    'form': 'first',
    'servings_per_container': 'first',
    'usage_direction': 'first',
    'other_ingredients': 'first',
}).reset_index()

# %%
df_merged
# Out:
#          id                                       product_name         type  \
# 0  01400030  French Pine Bark Extract - The Powerful Antiox...  Anti Ageing
# 1  01400140  French Pine Bark Extract - The Powerful Antiox...  Anti Ageing
# 2  01400240  French Pine Bark Extract - The Powerful Antiox...  Anti Ageing
# 3  01400670                    Radiance+ Premium Collagen Mask  Anti Ageing
# 4  01400940  French Pine Bark Extract - The Powerful Antiox...  Anti Ageing
# 5  01403960  Rejuvenate+ Premium Collagen 13,000mg plus Pla...  Anti Ageing
# 6  01403970                  NMN 450mg - Ultimate NAD+ Booster  Anti Ageing
# 7  01406400                  NMN 300mg - Ultimate NAD+ Booster  Anti Ageing
# 8  01406620                Miracle Intensive Age-Defying Serum  Anti Ageing
#
#                                       key_ingredient  \
# 0       Oligomeric proanthocyanidin complexes (OPCs)
# 1       Oligomeric proanthocyanidin complexes (OPCs)
# 2       Oligomeric proanthocyanidin complexes (OPCs)
# 3  Collagen, Glycerin, Sodium Hyaluronate, Tocoph...
# 4       Oligomeric proanthocyanidin complexes (OPCs)
# 5  Collagen, Mangosteen Extract, Placenta, Hyalur...
# 6                  NMN (Nicotinamide Mononucleotide)
# 7  NMN (Nicotinamide Mononucleotide), Grape Seed ...
# 8  Collagen, Glycerin, Sodium Hyaluronate, Tocoph...
#
#                                              storage  \
# 0  Store in a cool, dry place away from direct su...
# 1  Store in a cool, dry place. Avoid direct sunli...
# 2  Store in a cool, dry place away from direct su...
# 3  Store in a cool, dry place away from direct su...
# 4  Store in a cool, dry place away from direct su...
# 5  Store in a cool, dry place. Avoid direct sunli...
# 6  Store in a cool, dry place away from direct su...
# 7  Store in a cool, dry place away from direct su...
# 8  Store in a cool, dry place away from direct su...
#
#                                           precaution  \
# 0  If you are pregnant, nursing, taking any medic...
# 1  If you are pregnant, nursing, taking any medic...
# 2  If you are pregnant, nursing, taking any medic...
# 3  For external use only. Avoid direct contact wi...
# 4  If you are pregnant, nursing, taking any medic...
# 5  If you are allergic to seafood, consult your d...
# 6  If you are pregnant, nursing, taking any medic...
# 7  If you are pregnant, nursing, taking any medic...
# 8  For external use only. Avoid contact with eyes...
#
#                                             best_for     manufacturer  \
# 0                                                     The Netherlands
# 1                                                     The Netherlands
# 2                                                     The Netherlands
# 3                                                               Japan
# 4                                                     The Netherlands
# 5                                                               Japan
# 6  [A sedentary lifestyle, Age-related weight con...            Japan
# 7  [A sedentary lifestyle, Age-related weight con...            Japan
# 8                                                               Japan
#
#                                              feature  \
# 0  Premium Grade, Vegetarian, No Preservatives, N...
# 1  Premium Grade, Vegetarian, No Preservatives, N...
# 2  Premium Grade, Vegetarian, No Preservatives, N...
# 3           Premium Grade, Men and Women of all Ages
# 4  Premium Grade, Vegetarian, No Preservatives, N...
# 5  Premium Grade, RDS® Premium Collagen, No Artif...
# 6  Vegetarian, No Artificial Flavours, No Preserv...
# 7  No Artifical Colours, No Artificial Flavours, ...
# 8  Premium Grade, Men and Women of all Ages, No A...
#
#                                                 link              brand  \
# 0  https://www.lac.com/en/anti-ageing/lac-masquel...  LAC MASQUELIER's®
# 1  https://www.lac.com/en/anti-ageing/lac-masquel...  LAC MASQUELIER's®
# 2  https://www.lac.com/en/anti-ageing_beauty/lac-...  LAC MASQUELIER's®
# 3  https://www.lac.com/en/beauty/lac-taut%C2%AE/r...          LAC Taut®
# 4  https://www.lac.com/en/anti-ageing/lac-masquel...  LAC MASQUELIER's®
# 5  https://www.lac.com/en/beauty_collagen/lac-tau...          LAC Taut®
# 6  https://www.lac.com/en/anti-ageing/lac-anti-ag...    LAC Anti-Ageing
# 7  https://www.lac.com/en/anti-ageing_beauty/lac-...    LAC Anti-Ageing
# 8  https://www.lac.com/en/beauty/lac-taut%C2%AE/m...          LAC TAUT®
#
#   usual_price vip_price     form   servings_per_container  \
# 0       73.04     58.43   Tablet               50 tablets
# 1      391.92    313.54   Tablet              300 tablets
# 2      243.81    195.05   Tablet              175 tablets
# 3       38.85     31.08  Topical         5 sheets per box
# 4       35.38     28.30   Tablet               25 tablets
# 5       77.65     62.12   Liquid         50ml x 8 bottles
# 6      385.77    308.62     None  1.5g x 30 powder sticks
# 7      295.80    295.77  Softgel              30 softgels
# 8       72.27      0.00  Topical                    40 ml
#
#                                      usage_direction  \
# 0  Take 1 – 2 tablets per day with water or fruit...
# 1  Directions: As a dietary supplement, take 1 – ...
# 2  Take 1 – 2 tablets per day with water or fruit...
# 3  Use on cleansed face. Gently fit mask over eye...
# 4  Take 1 – 2 tablets per day with water or fruit...
# 5  Take 1 bottle, preferably before bedtime, at l...
# 6  Take 1 stick daily with juice or your favourit...
# 7                              Take 1 softgel daily.
# 8  Pump once or twice onto palm. Rub palms togeth...
#
#                                    other_ingredients
# 0  microcrystalline cellulose, magnesium stearate...
# 1  microcrystalline cellulose, magnesium stearate...
# 2  microcrystalline cellulose, magnesium stearate...
# 3  ingredients water, butylene glycol, glycerin, ...
# 4  microcrystalline cellulose, magnesium stearate...
# 5  citric acid, malic acid, sodium benzoate, oran...
# 6  indigestible dextrin, orange juice powder, mon...
# 7  grape seed oil, glycerol, silicon dioxide, gel...
# 8  water, butylene glycol, glycerin, citric acid,...

# %%
df.to_csv('product_details.csv', index=False)
print("Data has been written to 'product_details.csv'")
# Out:
# Data has been written to 'product_details.csv'
